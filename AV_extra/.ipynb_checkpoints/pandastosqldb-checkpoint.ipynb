# %%
import pandas as pd
df = pd.read_excel('Master_AV_List.xlsx')

# %%
df = df[1:4]

# %%
df.columns
# Out:
# Index(['UID', 'Original ID', 'Collection ID', 'Title', 'Series Title',
#        'Episode Title', 'Can Number', 'Original Can Number', 'Call Number',
#        'Date Created', 'Credits', 'Description', 'Summary', 'Location',
#        'Duration', 'Media Type', 'Copies', 'Base', 'Element', 'Vinegar Level',
#        'Notes', 'Preservation Action', 'Digital Preservation', 'Unnamed: 23'],
#       dtype='object')

# %%
import os 
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'AV_SCUA.settings')

import django 
django.setup()

# %%
from basic.models import AVItem

# %%
df_records = df.to_dict('records')

# %%
model_instances = [AVItem(
    uid=record['UID'],
    original_id=record['Original ID'],
    collection_id = record['Collection ID'],
    item_title = record['Title'],
    series_title = record['Series Title'],
    episode_title = record['Episode Title'],
    can_number = record['Can Number'],
    original_can_number = record['Original Can Number'],
    call_number = record['Call Number'],
    date_created = record['Date Created'],
    Credits = record['Credits'],
    description = record['Description'],
    location = record['Location'],
    format_duration = record['Duration'],
    media_type = record['Media Type'],
    copies = record['Copies'],
    Base = record['Base'],
    other_notes = record['Notes']
    digitial_preservation = record['Digital Preservation']
    lto_number = 
    status = 
    Copyright = 
    guage = 
    footage = 
    frame_rate = 
    color = 
    adv_color = 
    aspect_ratio = 
    anamorphic = 
    sound = 
    sound_content_type = 
    sound_field = 
    Clean = 
    resolution = 
    sample_encoding = 
    return_on_original_reel = 
    mold = 
    shrinkage = 
    ad_strip = 
    track_count = 
    stock = 
    

)]
# Out:
# [{'UID': 'AV00003',
#   'Original ID': 3,
#   'Collection ID': 'ISU Films',
#   'Title': '4-H boys club: Corn club project, Scott County, Iowa.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 003 335',
#   'Call Number': nan,
#   'Date Created': '1931',
#   'Credits': nan,
#   'Description': 'Farm field preparation, selecting corn, drying seed corn, comparing varieties, the harvesting committee, and the 1931 Scott County Iowa husking contest.',
#   'Summary': nan,
#   'Location': 'R1B S01',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'VHS copy? VH-0160. VHS needs cataloging (16mm only in Horizon)',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00019',
#   'Original ID': 20,
#   'Collection ID': 'ISU Films',
#   'Title': 'Agronomy, Industrial Education, Landscape Architecture.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 513',
#   'Call Number': nan,
#   'Date Created': '1941',
#   'Credits': nan,
#   'Description': 'Agronomy - Tells of soils and farm crop courses offered at Iowa State. Shows soil management students studying bacteria in the nodules of legumes, a field trip led by Professor Firkins on soil formations, taking soil samples, and testing for lime, the study of factors determining quality and market value of grain, and learning the methods of grading. Industrial Education - Tells how students are prepared to become teachers of Industrial Arts in junior and senior high schools, and shows the production of ornamental concrete garden vases, wood turning to make a bowl, and the casting of aluminum. Landscape Architecture - Shows students in the studio, planting a shrub, and studying a model homestead.',
#   'Summary': nan,
#   'Location': 'R1B S01',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy in Special Collections: DVD 001 513',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00036',
#   'Original ID': 54,
#   'Collection ID': 'ISU Films',
#   'Title': 'Best laid plans.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 000 726',
#   'Call Number': nan,
#   'Date Created': '1960',
#   'Credits': nan,
#   'Description': 'A rural family plans for a visit to the college of their daughters choice collide with the plans of an instructor.  She must decide whether to keep her own appointment or stay to confer with the family.',
#   'Summary': nan,
#   'Location': 'R1B S02 ',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': '2 copies. VHS & DVD copies: DVD 000 726/ Vide 004 479',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00043',
#   'Original ID': 61,
#   'Collection ID': 'ISU Films',
#   'Title': 'George Washington Carver.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 932',
#   'Call Number': nan,
#   'Date Created': '1967',
#   'Credits': nan,
#   'Description': "George Washington Carver at work in his lab and re-enactment of his childhood in Missouri, Fort Scott Kansas, his time in Iowa at Simpson and at Iowa State and his move to Tuskegee. \xa0Also shows people working cotton fields, tenant farmers, and talks about the boll weavel problem and Carver's uses for peanuts.",
#   'Summary': nan,
#   'Location': 'R1B S02',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 2,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': '2 copies',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00055',
#   'Original ID': 73,
#   'Collection ID': 'ISU Films',
#   'Title': 'Home economics at Iowa State College. [motion picture] / Food and Nutrition, Child Development',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 513',
#   'Call Number': nan,
#   'Date Created': 'ND',
#   'Credits': nan,
#   'Description': 'Shows students in the Food and Nutrition Department and how it operates, some of the labs, Institution Management, and the Tea Room.  Also activities in the Child Development Department with children of pre-school age.',
#   'Summary': nan,
#   'Location': 'R1B S03',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'Part 2',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00056',
#   'Original ID': 75,
#   'Collection ID': 'ISU Films',
#   'Title': 'Home economics at Iowa State College. Home Management House',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 501',
#   'Call Number': nan,
#   'Date Created': 'ND',
#   'Credits': nan,
#   'Description': 'Shows Home Economic seniors living at the Home management House for six week periods with an instructor and infant.  Also student teachers in towns around Ames, the selection of clothing for boys, and how to set a table.',
#   'Summary': nan,
#   'Location': 'R1B S03',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 2,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'Part 3, 2 copies',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00057',
#   'Original ID': 76,
#   'Collection ID': 'ISU Films',
#   'Title': 'Gibralter to Kent, England. / European Estates',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 401',
#   'Call Number': nan,
#   'Date Created': '1930',
#   'Credits': nan,
#   'Description': 'Landscape Architecture tour, summer 1930.  Views of the rock of Gibralter and the coast of Algeria as the party sails on the MV "Vulcania", street scenes in Algeria, and the ancient city of Syracuse on the island of Sicily.  The tour then went on to Egypt where they visited the port of Alexandria and the great pryamid of Cheops before heading on to Italy. In Venice they viewed the Doges Palace, the campanile on St. Mark\'s Square, the Palazzo Lezze on the Grand Canal, boated through the city.  It was then on to the gardens of Fontainbleau in France and the Chateau at Vaux-le-Vicomte near Melum designed by LeBrun, painter ; LaVaux, architect ; and LeNotre, landscape architect. In Paris, they visited the Gardens of Luxembourg.  In England the party visited Hampton Court along the Thames where they saw its perennial boarders, the King\'s Privy Garden, and Queen Anne\'s garden. They then took a bus tour of London and saw Tower Bridge, visited Kew Gardens, and traveled to Kent to see Groombridge Place gardens, owned by Mr. H. S. Mountain with house designed by Sir Christopher Wren and gardens by John Evelyn.',
#   'Summary': nan,
#   'Location': 'R1B S03',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00064',
#   'Original ID': 83,
#   'Collection ID': 'ISU Films',
#   'Title': 'Iowa State campus films. / campus scenes',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 443',
#   'Call Number': nan,
#   'Date Created': '1930',
#   'Credits': nan,
#   'Description': '119 -  Shows scenes of central campus, the Campanile, Marston Hall, the WOI tower, Mr. Ekberg by Lake LaVerne, a bon fire, and aerial views of the Iowa State campus and surrounding countryside.  121 - The 1930 Dairy Cattle Congress as members of the Cow Testing Association compete in a judging contest, also shows the Dairy Extension Service bull.',
#   'Summary': nan,
#   'Location': 'R1B S03 ',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00065',
#   'Original ID': 84,
#   'Collection ID': 'ISU Films',
#   'Title': 'Iowa State campus films.  / campus scenes',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 444',
#   'Call Number': nan,
#   'Date Created': '1936',
#   'Credits': nan,
#   'Description': '116b - 4-H convention ceremony program held on the ISC central campus.  117 - Shows the dedication ceremony for the original fountain on the north side of the Memorial Union before the addition of the Peterson statues.  Also the filling of Lake LaVerne, ringing of the Victory Bell located west of Beardshear Hall, and Carrie Chapman Catt posing with President Friley, Dean Emeritus Marsont, and Dean T.R. Agg.  118-Scenes of campus in winter, the easter egg hunt on central campus, a VEISHEA float, M.D. Helser greeting Athletic Council members R.A. Runnels, T.R. Agg, C.H. Brown, W.L. "Pop" Foster, Ralph Thomson, Guy Lambert, and A.J. "Spike" Crawford.  Also shows T.N. Metcalf and his dog Becky.',
#   'Summary': nan,
#   'Location': 'R1B S03',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00071',
#   'Original ID': 90,
#   'Collection ID': 'ISU Films',
#   'Title': 'Home economics at Iowa State College.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 514',
#   'Call Number': nan,
#   'Date Created': 'ND',
#   'Credits': nan,
#   'Description': 'Shows students leaving MacKay Hall at Iowa State and the types of subjects studied in the Department of Home Economics. Applied art students work on various painting projects, interior design, and costume design.  Also household equipment corses where student test water and washing methods, dryers, and clothes presses.',
#   'Summary': nan,
#   'Location': 'R1B S04',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00075',
#   'Original ID': 96,
#   'Collection ID': 'ISU Films',
#   'Title': 'Venice Italy to Philadelphia, Pennsylvania.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 399',
#   'Call Number': nan,
#   'Date Created': '1930',
#   'Credits': nan,
#   'Description': 'The tour group travels between Venice and Innsbruck, Austria through the Alps by train and then on to France. There they visited Versailles where they saw the fountains, circular colonnade of Mansart, and fireworks in the Basin of Neptune. They also visited Fontainbleau, Napolean\'s island pavilion, and saw the long canal and fountain.\n520\t0  \t$aThe tour then went on to Vaux-le-Vicomte near Melum with the chateau that was owned by Mons. Alfred Domier and garden designed by LeNotre. While there they also saw the service buildings and stables, and the statue of Hercules at the termination of the main garden axis.\n520\t0  \t$aIt was then on to Paris and the Champs d\'Elysees, Malmaison, favorite home of Napolean and Josephine, St. Germaine Terrace designed by LeNotre with views of Paris, the Seine river and clipped Horse Chestnuts. They also saw Notre Dame, Jardin des Plantes, and a nearby Turkish mosque.\n520\t0  \t$aIn England the party traveled to Kent to see Groombridge Place gardens and stables, owned by Mr. H. S. Mountain with house designed by Sir Christopher Wren and gardens by John Evelyn and went to see Brockhurst. Salt was then homeward bound on the SS "Statesman" and a visit to Philadelphia looking up Fairmont Parkway toward the new museum ( Philadelphia Museum of Art ).',
#   'Summary': nan,
#   'Location': 'R1B S04',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 399 Alternate title: Italy to Pennsylvania',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00076',
#   'Original ID': 97,
#   'Collection ID': 'ISU Films',
#   'Title': 'St. Petersburg Florida to West Palm Beach Florida.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 512',
#   'Call Number': nan,
#   'Date Created': '1931',
#   'Credits': nan,
#   'Description': '1931 LA ( landscape architecture ) 142c trip.\n520\t   \t$aIowa State College Landscape Architecture Professor Elwood takes students on a tour of the southern and eastern United States. Shows stops at the Great Pier in St. Petersburg along with hibiscus and grapefruit orchards in the area.\n520\t0  \t$aFrom there they traveled on to Coral Gables where they visited a Venitian poll with a refreshment porch and saw one of the formal entrances. It was then on to the Deering Estate in Coconut Grove.\n520\t0  \t$aFrom there it was on to Palm Beach via Ocean Drive where they visited Memorial Park, West Palm Beach patio gardens, The Everglades Club designed by Mr. Meisner, and saw the arcade of business street.',
#   'Summary': nan,
#   'Location': 'R1B S04',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 512 Alternate title: Florida',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00077',
#   'Original ID': 98,
#   'Collection ID': 'ISU Films',
#   'Title': 'Hong Kong to Amoy China.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 505',
#   'Call Number': nan,
#   'Date Created': '1929',
#   'Credits': nan,
#   'Description': '1929 LA ( landscape architecture ) 142c trip.\n500\t   \t$aIowa State College Landscape Architecture Professors Elwood and Popham take 4 students, Bethane Carpenter, John Hall, Max Bird and Norman Morris, on a tour of Japan, China, Phillipine and Hawaian Islands.\n520\t   \t$aA panorama of Hong Kong from the Peak Hotel, Repulse Bay Hotel and bathing beach with thatched bath houses, and views of Hong Kong from Kowloon.\n520\t0  \t$aIt is then on to Canton China, where the tour group sees the spproach to Island Park, flowery Pagoda, overlook the Great Cemetery, see the Sun Yet Sen Monument under construction and ancient Chinese temples. Also in Canton they see a monument to the Republic of China with a replica of the Statue of Liberty, a memorial to 77 martyrs of the Chinese Republic, cultivating rice fields and planting rice by hand, a native village, and the foreign settlement across the canal from the city.\n520\t0  \t$aLeaving Canton for Hong Kong they see chinese Junks on the Pearl River, the Hong Kong harbor, and while enroute to Formosa, ( Taiwan ) the ships captain shows them his Chow puppies. It is then on to the southern coast of China near Amoy.',
#   'Summary': nan,
#   'Location': 'R1B S04',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 505 Alternate title: Hongkong to Formosa',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00079',
#   'Original ID': 110,
#   'Collection ID': 'ISU Films',
#   'Title': 'Iowa State campus films.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 445',
#   'Call Number': nan,
#   'Date Created': '1939',
#   'Credits': nan,
#   'Description': '193 - Disclaimer made by Iowa State College Extension Service to be shown prior to a Bayer-Semesan Company sponsored film about seed diseases. 195 - Same disclaimer as in 193 along with ending statement also produced by the Extension Service telling farmers what additional information they should know about seed treatment. Shows students, faculity, staff and families at Camp Marston on Rainy Lake Minnesota. Shows the journey by boat from town passing under the drawbridge and arriving at camp. Shows many of the everyday activities at the camp such as fishing, doing laundry, chopping wood, playing games such as horseshoes, cards, swimming, boating, and table tennis. Also shows people gathering for group photographs and meals along with local wildlife.',
#   'Summary': nan,
#   'Location': 'R1B S04',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00080',
#   'Original ID': 111,
#   'Collection ID': 'ISU Films',
#   'Title': 'Dr. Melhus.  / Campus films',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 446',
#   'Call Number': nan,
#   'Date Created': '1935',
#   'Credits': nan,
#   'Description': 'Shows Dr. Melhus sitting on a bench in his yard at 407 Pearson with his dog at his feet. Also shows his wife sitting in a chair in the yard with the dog.',
#   'Summary': nan,
#   'Location': 'R1B S04',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00085',
#   'Original ID': 116,
#   'Collection ID': 'ISU Films',
#   'Title': 'Iowa State campus films',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 447',
#   'Call Number': nan,
#   'Date Created': '1932',
#   'Credits': nan,
#   'Description': '131 - (b&w) - A baby, women looking at flowers by a house, groups of people pose for the camera, men and boys walk through a bean field, (b&w neg) - men cut open and eat watermelon in the patch, a man demonstrates roping by roping another man, men get antlers and other things out of an automobile, one man holds antlers up to his head and acts like a deer.',
#   'Summary': nan,
#   'Location': 'R1B S04',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00088',
#   'Original ID': 119,
#   'Collection ID': 'ISU Films',
#   'Title': 'Iowa State campus films',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 448',
#   'Call Number': nan,
#   'Date Created': '1938',
#   'Credits': nan,
#   'Description': 'A young man driving a convertible in winter picks up his date from her residence hall and they drive off. Couples order from a waiter at a resturant, a couple walks around Lake LaVerne while a man feeds the swans Lancelot and Elaine, and other couples lay on blankets near to lake to study. A "five pound party" where a girl enters the room and all her friends are gathered around a large table and there is a box of candy waiting to be opened. Inside the box there is a ring box and then they pass the candy around. After that there are pictures from a wedding. Also there are scenes of people walking around on campus by the Hub and other buildings, a policeman riding by on a motocycle, girls playing cards, Mr. Chase at the organ in the Great hall of the Memorial Union, the Campanile and carrilon with Mr. Schroeder, and masons working on the area in front of the bas relief at the Vet Quad where the "Gentle Doctor" will be installed.',
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00089',
#   'Original ID': 120,
#   'Collection ID': 'ISU Films',
#   'Title': 'Iowa State campus films',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 449',
#   'Call Number': nan,
#   'Date Created': '1940',
#   'Credits': nan,
#   'Description': 'Shows students in different areas of study at Iowa State. Included are laboratory scenes where students are preparing petri dishes and slides of bacteria for microscopic study, a soil survey field trip to a building excavation site, the taking of soil samples, a visit to a flood plain to how streams have changed course, and the study of minerals in rocks and soil. Also shows students in the study of the market grading of farm crops, hybrid corn experiments and the sorting of seed, Industrial Education students mixing concrete and pouring it into a mold for a garden vase, a student turning a wooden bowl on a lathe, and students casting aluminum. Finally shows Landscape Architecture students in the studio, planting a tree, and examining a model of a farmstead.',
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00090',
#   'Original ID': 121,
#   'Collection ID': 'ISU Films',
#   'Title': 'Formosa to Oregon',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 506',
#   'Call Number': nan,
#   'Date Created': '1929',
#   'Credits': nan,
#   'Description': 'Iowa State College Landscape Architecture Professors Elwood and Popham take 4 students, Bethane Carpenter, John Hall, Max Bird and Norman Morris, on a tour of Japan, China, Phillipine and Hawaian Islands. Amoy China the group first visits the home of Wai Joe, then see Camel Rock from the garden of a merchant, and see the private garden of another wealthy Chinese merchant. From there it is on to Formosa ( Taiwan ) and a shrine at Keelung, ( Chi-Lung ) and a visit to the city square. It is then on to Taihoku ( Taipei ) to see a Chinese temple and Japanese shrine. a great camphor tree near the inn, and the proprietress and daughter of the Asumya Inn, Tianan. Also on the islad they pass by banana orchards, rice firlds, bamboo groves, chinese homes, and distant mountains. They then travel back to Japan where they see wayside wanderers by the road, Mt. Hiei and Lake Biwa, wayside shrines, giant cryptomerias. they also see the Garden of the Golden Pavilion, Kinkakuji, glimpse Koyoto gardens, meet Professor Sekiguchi and Mr. Ida, their guides and hosts in Kyoto, see the entrance Garden gateway to Horai Garden, and a street in Tokyo showing newly planted trees. Sailing from Yokohama on board the "Arabia Maru" they cross the "gentel" Pacific for the port of Victoria, British Columbia. From they they begin they journey back to Iowa by passing through the Cascade Mountains between Seattle and Portland.',
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 506',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00091',
#   'Original ID': 122,
#   'Collection ID': 'ISU Films',
#   'Title': 'Kamakura Japan to Peking China',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 398',
#   'Call Number': nan,
#   'Date Created': '1929',
#   'Credits': nan,
#   'Description': '1929 LA ( landscape architecture ) 142c trip.\n500\t   \t$aIowa State College Landscape Architecture Professors Elwood and Popham take 4 students, Bethane Carpenter, John Hall, Max Bird and Norman Morris, on a tour of Japan, China, Phillipine and Hawaian Islands.\n520\t   \t$aThe touring party has a meeting with Landscape Architects Dr. Uyehara and Paul Tono, visits the Great Diabutsu and the entrance to an ancient temple in Kamakura. From ther they traveled to Nikko where they visited the Great Tombs of the Shoguns, the entrance to the Nikko Temple, and see great cryptomeria overshadowing the Great Temple of Nikko.\n520\t0  \t$aFrom Japan they travel to Peking they see workers watering a street and visit the Forbidden City where thy view the winter palce and a minor entrance. From there they take a trip to Pei Hai plow through the lotus in the Golf of Tonkin, view Chinese temples, and see Coal Hill. Back in Peking they travel near the presidents palace, view the private gardens of the Neatherlands Syndicate, the Llama Temple grounds, the Temple of Confucius, the Spirit Stairway, Hall of Classics, the Porcelain Pagoda in the Western Hills near the Summer palace, the Jade Fountain, Echo Temple, and the Temple of Heaven.',
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 398 Alternate title: Japan- China',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00093',
#   'Original ID': 124,
#   'Collection ID': 'ISU Films',
#   'Title': 'Iowa State campus films',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 450',
#   'Call Number': nan,
#   'Date Created': '1939',
#   'Credits': nan,
#   'Description': '163 - (b&w) - Campus gardener Eckberg and some of his handiwork, (color) - Crown Prine Fredrik and Princess Ingrid of Denmark visit Iowa State and the Memorial Union.  164 - (b&w) - Dedication of Clyde Williams Field.  165 -(color) - football game highlights, the marching band on the field for the 1939 Homecoming, and the Memorial Union.  166 - (color) - A bi-plane and single wing small airplanes fly over central Iowa, land and take off from an airport, football highlights, graduation on the Iowa State central campus.  171 - (b&w) - title slides for campus film #165.',
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00094',
#   'Original ID': 125,
#   'Collection ID': 'ISU Films',
#   'Title': 'Iowa State campus films',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 451',
#   'Call Number': nan,
#   'Date Created': '1934',
#   'Credits': nan,
#   'Description': '114 - (color) - Scenes around campus including the flagpole on central campus, Botany Hall (Catt Hall), Morrill Hall, Armory, and Marston Hall.  Also Lancelot and Elaine on Lake LaVerne, ducks, the Memorial Union, the Maples (Music Hall), the Campanile, campus gardener Mr. Eckberg and night watchman Mr. Heglund. 115 - Memorial Union, people lining the street waiting for a parade, traffic on the street between the Campanile and Union, people entering West Gate, a football game and ice hockey on Lake LaVerne.  116a - Band members outside of State Gym, bands practicing in State Gym, aerial views of the Iowa State campus, and a class meeting outdoors.',
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00095',
#   'Original ID': 126,
#   'Collection ID': 'ISU Films',
#   'Title': 'South Dakota to Montana',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 395',
#   'Call Number': nan,
#   'Date Created': '1927',
#   'Credits': nan,
#   'Description': "A record of Professor Elwood's trip with Landscape Architecture students Breeze, Vinton and Hanford through the US west in an Essex sedan covering 10,000 miles.  Shows some of the highlights of a tour of US western National Parks in 1927 by Professor Elwood and three Landscape Architecture students from Iowa State College. In South Dakota they visited Cedar Canyon, the Badland's National Monument, the summer home of President Coolidge and saw Mrs. Coolidge out on the porch, and climed Harney's Peak, the highest in the Black Hills ans visited the fire watch station there manned by an Iowa State graduate.  From there they traveled on to Yellowstone National Park where they saw the Grand Canyon of the Yellowstone, Upper and Lower Falls, Old Faithful, Mt. Washburn, and has close encounters with bears.  It was then on to Glacier National Park where they arrived on July 3rd and spent the next five days. While there they visited Lake McDermott and hiked the Gunsight Pass.",
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 395 Alternate title: South Dakota and Wyoming Trip',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00096',
#   'Original ID': 127,
#   'Collection ID': 'ISU Films',
#   'Title': 'Kamakura Japan to Hong Kong',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 504',
#   'Call Number': nan,
#   'Date Created': '1929',
#   'Credits': nan,
#   'Description': '1929 LA ( landscape architecture ) 142c trip.\n500\t   \t$aIowa State College Landscape Architecture Professors Elwood and Popham take 4 students, Bethane Carpenter, John Hall, Max Bird and Norman Morris, on a tour of Japan, China, Phillipine and Hawaian Islands.\n520\t   \t$aFrom on the train between Kamakura and Kyoto we see prosperous rice farms and then it is on to the sacred island of Miyajima ( Itsuku-Shima ) before heading on to Seoul, Korea. There we see the city from the Temple heights and their Korean guide in the markets.\n520\t0  \t$aIt is then on to Shanghai, the gateway to China, where the tour takes them by a wilow patern tea house, temples, and the harbor Whang-poo River where they see foreign battleships at anchor.\n520\t0  \t$aNext is their approach to Hong Kong, a distant view of the peak, the upper deck of C.P. SS "Empress of Russia", and views of Hong Kong from the docks at Kowloon.',
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 504 Alternate title: Japan to Hong Kong',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00098',
#   'Original ID': 129,
#   'Collection ID': 'ISU Films',
#   'Title': 'VEISHEA:  Iowa State College',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 391',
#   'Call Number': nan,
#   'Date Created': '1942',
#   'Credits': nan,
#   'Description': 'Iowa State University VEISHEA, (Veterinary medicine, Engineering, Industrial Science, Home Economics, Agriculture) celebration of 1942 with the evening and opening ceremony, arrival of the queens at Lake LaVerne, President Hancher\'s speech, crowning of the "Queen of Queens", and the presentation of the years frist "Bombs" (yearbooks).  (color)  Dedication of the new Christian Petersen fountain in front of MacKay Hall, the military review, graduation and presentation of awards on the field where Design and Howe Halls are now located, and highlights of the parade with marching bands and floats.',
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 391',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00099',
#   'Original ID': 130,
#   'Collection ID': 'ISU Films',
#   'Title': 'Campus views:  Iowa State College',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 510',
#   'Call Number': nan,
#   'Date Created': '1939-1944',
#   'Credits': nan,
#   'Description': "Shows many scenes of the Iowa State campus during the different seasons.  Includes views of the Press Building, Veterinary Clinic, Insectary, spring near the women's residence halls, Women's Gym, fall colors and the Campanile, winter near the Hub, Marston, Beardshear, Campus Creek and Lake LaVerne.  Also shows the Pammel Court trailers, a woman with a baby outdoors on a blanket, and some campus personalities playing badminton and riding bicycles.",
#   'Summary': nan,
#   'Location': 'R1B S05',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 002 510',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00105',
#   'Original ID': 138,
#   'Collection ID': 'ISU Films',
#   'Title': 'Washington to California.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 502',
#   'Call Number': nan,
#   'Date Created': '1927',
#   'Credits': nan,
#   'Description': 'Shows some of the area around Paradise Inn in Mt. Ranier National Park, the loading of logs onto a Japanese steamship for export in the ports of Longview, the Columbia River valley and Mt. Momo Falls.  From there they traveled on to Portland Oregon, visited Crater Lake National Park, San Francisco California, Stanford University, Point Lobos in Monterey, and Yosemite and Vernal Falls.',
#   'Summary': nan,
#   'Location': 'R1B S06',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 502',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00106',
#   'Original ID': 139,
#   'Collection ID': 'ISU Films',
#   'Title': 'California to Iowa.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 503',
#   'Call Number': nan,
#   'Date Created': '1927',
#   'Credits': nan,
#   'Description': 'In California the group tours Sequoia National Park, Moro Rock National Park, the gardens of Edward L. Doheny in Beverly Hills, Wiltshire Blvd. in Los Angeles, and views the Spanish Mission style architecture in Balboa Park and views the San Diego Exposition grounds from atop the tower.  From there they traveled on to see the Grand Canyon of the Colorado, payed a visit to a Zuni Indian village near Gallup New Mexico, and went to Mesa Verde National Park where they climbed up the ladder to visit the cliff house village.  It was then on to the Rockey Mountains and the city of Ouray, the Rocky Mountain National Park above Ested Park, and then shows them arriving back in Ames where they were just in time for the marching bands at the annual Shrine picnic on central campus.',
#   'Summary': nan,
#   'Location': 'R1B S06',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 503 Alternate title: California to Ames',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00108',
#   'Original ID': 141,
#   'Collection ID': 'ISU Films',
#   'Title': 'Campus films / Golf.',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 797',
#   'Call Number': nan,
#   'Date Created': '1933',
#   'Credits': nan,
#   'Description': 'Men and women playing golf at the tee, on the fairway, puttin, and on the practice green.  Also a large picnic at the clubhouse of the Ames Golf and Country Club when it was located east of the Iowa State Dairy Farm on Mortensen Road.',
#   'Summary': nan,
#   'Location': 'R1B S06',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00113',
#   'Original ID': 147,
#   'Collection ID': 'ISU Films',
#   'Title': 'Campus films / Agriculture at Iowa State',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 446',
#   'Call Number': nan,
#   'Date Created': '1955',
#   'Credits': nan,
#   'Description': 'Dean Kildee examines some of the trophies won by Iowa State agriculture students. Shows draft horse judging outside of the horse barns on campus, cattle feed experiments, live and carcass cattle judging, brood sow observation, and preparing animals for show. Also shows Dairy Husbandry students, Poultry Husbandry students numbering eggs and banding chicks, Agricultural Engineering tractor operation study, and Horticulture students doing tree grafting, peony and iris production, and pruning.',
#   'Summary': nan,
#   'Location': 'R1B S06',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00115',
#   'Original ID': 149,
#   'Collection ID': 'ISU Films',
#   'Title': 'Campus films / Home economics at Iowa State',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 516',
#   'Call Number': nan,
#   'Date Created': 'ND',
#   'Credits': nan,
#   'Description': 'Looks at the eight department in the College of Home Economics.  Applied art students decorate fabirc, paint, work with metal, learn about furnishing on a budget, flower arrangement, and critque art.  Textile and Clothing students learn about purchasing fabrics, designing clothing, and fitting patterns.  Also household equipment courses where student learn about selecting, operating and the care of household appliances along with commercial training, and the testing of washing and drying methods.',
#   'Summary': nan,
#   'Location': 'R1B S06',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00125',
#   'Original ID': 159,
#   'Collection ID': 'ISU Films',
#   'Title': 'Wilmington Delaware to Lake Forest Illinois',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 508',
#   'Call Number': nan,
#   'Date Created': '1931',
#   'Credits': nan,
#   'Description': '1931 LA ( landscape architecture ) 142c trip.\n520\t   \t$aA record of a trip taken by professor Elwood and students from the Landsacape Architecture Department of Iowa State College. Places visited on the trip include - "Longwood", DuPont gardens near Wilmington, Del. ; R. T. Stotesbury gardens, Chestnut Hill, Philadelphia, Jacques Grebey, Landscape Architect ; the Wissahickon Parkway, Philadelphia ; "Old Ironsides" or "USS Constitution, built 1794, rebuilt in 1927, docked at New London, Conn. ; new Harvard University Dormitories along the Charles River .\n520\t0  \t$aAlso the garden of Gerard Foster, Bellefontaine, Lennox, Mass. And the forecourt showing the replica of the famous Boboli goats ; home of P. H. Elwood Jr., Fort Plains, New York ; looking toward Cooperstown from along Otsego Lake, New York, site of leatherstocking Tales ; in the garden of the late E. Gorton Davis, Ithaca, New York ; Creeping Bent Hall ; Cleveland Art Museum and garden ; four representivities of Iowa State College at the Lake Forest Foundation for Architects and Landscape Architcts ; and the Rierson Garden, Lake Forest, Ill.',
#   'Summary': nan,
#   'Location': 'R1B S07',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 508 Alternate Title: Elwood East Coast Trip',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00126',
#   'Original ID': 160,
#   'Collection ID': 'ISU Films',
#   'Title': "Cyprus to Florence, Italy / Villa D'Este",
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 001 400',
#   'Call Number': nan,
#   'Date Created': '1930',
#   'Credits': nan,
#   'Description': 'Tours the Villa d-Este east-northeastin of Rome where they see the Allee of 100 Fountains, the Water Organ Foundation, the unfinished casino at the end of the main axis, the Dragon Fountain, Lily Fountain, and views of the distant hills.  The tour then went on to the port of Limassal on the island of Cyprus where the SS "Brasile" is shown.  From there they traveled to Turkey to see the Mosque St. Sophia in Constantinople (Istanbl), the harbor, new Royal Palace, and area near Roberts College, another mosque and ancient fortifications along the Bosphorus.  It was then on to the island of prinkipe, (B_y_kada), where they see glimpses of Trotsky\'s home which ahd recently burned and then on to Athens. There they visit the Temple of Jupiter (Zeus), view the city from the Acropolis, lookdown on the Amphitheater, examine the Parthenon with the restored north elevation, the porch of Caryatide, and visit modern buildings and ground in Athens designed in a classic style.  They then went through the Corinth Canal and on to Naples, Italy where they view Mount Vesuvius from the Hotel Bertolini.  It was then on to Rome and the Farnese palace Gardens, Palatine hill, Borghese gardens, and Villa Torlonia.  Then traveling north they visit Villa Gamberaia at Settignano near Florence, Villa Turri-Salviati where they have views of Fiesole and Villa Pamieri that was restored by James W. Ellsworth of Cleveland Ohio.  From there they took in the view of Florence from the Villa and its upper terrace.',
#   'Summary': nan,
#   'Location': 'R1B S07',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'DVD copy: DVD 001 400',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00134',
#   'Original ID': 168,
#   'Collection ID': 'ISU Films',
#   'Title': 'Iowa State campus films',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 452',
#   'Call Number': nan,
#   'Date Created': '1944, 1947',
#   'Credits': nan,
#   'Description': '409-(color, 1944)-Shows various scenes around campus including Marston Hall, two trophies on a table outside of the country club, Navy students crossing the street, residence halls, and the physical education building (Forker Hall).  410-(color, 1947)-The crowning of the VEISHEA Queen of Queens.  411-Possibly members of the Iowa State football staff sitting at a desk reviewing a book, students leaving a residence that has been decorated for homecoming, and Beardshear Hall.  412-(color, 1947)-"May daze for married" or "Mr. and Mrs. Week end" held along Tower road in Pammel Court on the Iowa State campus May 3rd and 4th.  Shows some of the childrens costume parade, pony rides, adult entertainment, games and food available.',
#   'Summary': nan,
#   'Location': 'R1B S07',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00139',
#   'Original ID': 173,
#   'Collection ID': 'ISU Films',
#   'Title': 'Agricultural Frontiers',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 924',
#   'Call Number': nan,
#   'Date Created': 'ND',
#   'Credits': nan,
#   'Description': 'Tells the story of agriculture in Iowa from the time of the first settlers up to 1927.  Discusses the family farm, types of crops grown, and shows some of the farm equipment used through histroical reenactments.',
#   'Summary': nan,
#   'Location': 'R1B S07',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00161',
#   'Original ID': 200,
#   'Collection ID': 'ISU Films',
#   'Title': '(Europe trip)',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': '20-0053',
#   'Call Number': nan,
#   'Date Created': '1954',
#   'Credits': nan,
#   'Description': 'Part 1 - Shows the family leaving on a Cunard Lines liner for a trip to Europe. Shows some of the activities on board the ship, the Killarney Cork Ferry transporting passengers from the ship, Paris France and the Eiffel Tower, sights in Italy including a steel mill and Rome, mountains and mountain villages, Weissenburg, roadsigns to Br\x11FC\x12nig Luzern and Meiringen, paddleboating on a river, and street vendors selling vegetables.',
#   'Summary': nan,
#   'Location': 'R1B S12',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': '1 of 2',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00162',
#   'Original ID': 201,
#   'Collection ID': 'ISU Films',
#   'Title': '(Europe trip)',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': '20-0053',
#   'Call Number': nan,
#   'Date Created': '1954',
#   'Credits': nan,
#   'Description': 'Part 2 - Berlin Germany and the sign saying "You are now leaving the British sector", destruction from World War II, a soccer game, castles, houses, trains and other boats on a river, and a helicopter trip to see sights. Also sights in Holland and a town square where paintings are being sold, a ferry trip, windmills and tulip gardens, and shipyards. Finally on to England and the site of the "Lion Tower, AD 1250", the English countryside, and airplanes takinf off.',
#   'Summary': nan,
#   'Location': 'R1B S12',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': '2 of 2',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00165',
#   'Original ID': 205,
#   'Collection ID': 'ISU Films',
#   'Title': 'Khruschev and Garst, Coon Rapids',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 994',
#   'Call Number': nan,
#   'Date Created': '1959',
#   'Credits': nan,
#   'Description': 'Clips of the Krushchev visit to the Garst farm, in Coon Rapids, Iowa and the John Chrystal farm.',
#   'Summary': nan,
#   'Location': 'R1B S12',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00168',
#   'Original ID': 208,
#   'Collection ID': 'ISU Films',
#   'Title': "Khruschev at Garst's farm",
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 993',
#   'Call Number': nan,
#   'Date Created': '1959',
#   'Credits': nan,
#   'Description': 'Clips of the Krushchev visit to the Garst farm touring the fields and with the family.  Also some of the signs in Coon Rapids Iowa store windows that were written in Russian.',
#   'Summary': nan,
#   'Location': 'R1B S12',
#   'Duration': nan,
#   'Media Type': 'DVD',
#   'Copies': 1,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV00169',
#   'Original ID': 209,
#   'Collection ID': 'ISU Films',
#   'Title': 'Elizabeth Garst',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': 'DVD 002 992',
#   'Call Number': nan,
#   'Date Created': '1983',
#   'Credits': nan,
# ...
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01914',
#   'Original ID': 725,
#   'Collection ID': 'ITC',
#   'Title': 'Neuro-anatomy - Dog',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S53',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01915',
#   'Original ID': 726,
#   'Collection ID': 'ITC',
#   'Title': 'Iowa Medal Award Ceremony',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': 'J. V. Atanasoff',
#   'Summary': nan,
#   'Location': 'R2B S53',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'Atanasoff gets Iowa Award. Save all materials.',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01916',
#   'Original ID': 727,
#   'Collection ID': 'ITC',
#   'Title': 'Iowa Conservation Commission Credit (ICC)',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S53',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01917',
#   'Original ID': 728,
#   'Collection ID': 'ITC',
#   'Title': 'U. of OK. vs ISU BB',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S53',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01918',
#   'Original ID': 729,
#   'Collection ID': 'ITC',
#   'Title': 'Iowa 2000',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S53',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01919',
#   'Original ID': 730,
#   'Collection ID': 'ITC',
#   'Title': 'Replace Damaged Print',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S53',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01920',
#   'Original ID': 731,
#   'Collection ID': 'ITC',
#   'Title': 'Soil Contour',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': 'Ag Engineering, Lovely and Lutrel',
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01921',
#   'Original ID': 732,
#   'Collection ID': 'ITC',
#   'Title': 'Football Film Splicing',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01922',
#   'Original ID': 733,
#   'Collection ID': 'ITC',
#   'Title': 'Time and a Place (A) - Sioux city',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01923',
#   'Original ID': 734,
#   'Collection ID': 'ITC',
#   'Title': 'Frank-a-matic Film Repair',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01924',
#   'Original ID': 735,
#   'Collection ID': 'ITC',
#   'Title': 'Campus, Capitol Building, Livestock, Sports',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': 'Stock footage',
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'Save all original material.',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01925',
#   'Original ID': 736,
#   'Collection ID': 'ITC',
#   'Title': 'Ames Lab - Terfanol D',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01926',
#   'Original ID': 737,
#   'Collection ID': 'ITC',
#   'Title': 'Traffic Survey',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': 'Stock footage',
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01927',
#   'Original ID': 738,
#   'Collection ID': 'ITC',
#   'Title': 'Hi Speed Cine - Chem Engr (Canceled)',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01928',
#   'Original ID': 739,
#   'Collection ID': 'ITC',
#   'Title': 'Soil Erosion - Lightning Hitting Barn Simulation',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': 'Stock footage',
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01929',
#   'Original ID': 740,
#   'Collection ID': 'ITC',
#   'Title': 'Film Sound Mix Service',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01930',
#   'Original ID': 741,
#   'Collection ID': 'ITC',
#   'Title': 'Iowa Crop Development',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01931',
#   'Original ID': 742,
#   'Collection ID': 'ITC',
#   'Title': 'Fall 1985 Football Game Films',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S54',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01932',
#   'Original ID': 743,
#   'Collection ID': 'ITC',
#   'Title': 'LIly Time Lapse',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': 'WOI-TV',
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01933',
#   'Original ID': 744,
#   'Collection ID': 'ITC',
#   'Title': 'Film Sound Re-mix',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1985',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01934',
#   'Original ID': 745,
#   'Collection ID': 'ITC',
#   'Title': 'Moving of Westgate',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'Documents the moving of the ISU Westgate pillars so the street could be widened.',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01935',
#   'Original ID': 746,
#   'Collection ID': 'ITC',
#   'Title': 'Univ. of OK. vs ISU BB',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1986',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01936',
#   'Original ID': 747,
#   'Collection ID': 'ITC',
#   'Title': 'Roller-Sheller',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': 'Ron Brass',
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01937',
#   'Original ID': 748,
#   'Collection ID': 'ITC',
#   'Title': 'Braced for Action',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1986',
#   'Credits': nan,
#   'Description': 'Student Brace Film',
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': 'Student film sold andistributed by ISU. Check copyright. Save all ABC printing rolls, optical sound tracks (A and B-wind) and InterNeg and/or  Inter/Pos and Dupe/Neg printing rolls.',
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01938',
#   'Original ID': 749,
#   'Collection ID': 'ITC',
#   'Title': 'Fabrics on the Move',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': 'State University of Iowa (SUI)',
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01939',
#   'Original ID': 750,
#   'Collection ID': 'ITC',
#   'Title': 'Student Exposure Meter Film (Canceled)',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1986',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01940',
#   'Original ID': 751,
#   'Collection ID': 'ITC',
#   'Title': 'Chicken Drinking',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': nan,
#   'Credits': nan,
#   'Description': 'Hollander',
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  {'UID': 'AV01941',
#   'Original ID': 752,
#   'Collection ID': 'ITC',
#   'Title': '1986 Spring Football Scrimmages',
#   'Series Title': nan,
#   'Episode Title': nan,
#   'Can Number': nan,
#   'Original Can Number': nan,
#   'Call Number': nan,
#   'Date Created': '1986',
#   'Credits': nan,
#   'Description': nan,
#   'Summary': nan,
#   'Location': 'R2B S55',
#   'Duration': nan,
#   'Media Type': 'Film',
#   'Copies': nan,
#   'Base': nan,
#   'Element': nan,
#   'Vinegar Level': nan,
#   'Notes': nan,
#   'Preservation Action': nan,
#   'Digital Preservation': nan,
#   'Unnamed: 23': nan},
#  ...]
